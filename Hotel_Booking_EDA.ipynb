# %% [markdown]
# <a href="https://colab.research.google.com/github/sudipsingh104/EDA_Hotel/blob/main/Hotel_Booking_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ***Hotel Booking Analysis***
#
#
# ---
#
#
#
#
#
# The Hotel Booking Analysis project aims to explore and analyze data related to hotel bookings to gain valuable insights and assist hotel management in making informed decisions. The dataset used in this analysis contains information about hotel types, cancellations, customer is regular or not, kind of booking, which moth has highest booking and other relevant features.
#
# Key Objectives:
#
# 1. Data Exploration: Begin by understanding the structure of the dataset, including the number of rows and columns, data types, and basic summary statistics. Identify potential data quality issues and missing values that need to be addressed.
#
# 2. Data Cleaning: Preprocess the data by handling missing values, duplicates, and outliers. Clean and transform the data to ensure its integrity and reliability for analysis.
#
# 3. Exploratory Data Analysis (EDA): Conduct in-depth exploratory analysis to uncover patterns and trends in hotel bookings. Investigate factors like seasonal booking trends, peak booking periods, average length of stay, and preferred room types.
#
# 4. Customer Segmentation: Segment customers based on various criteria such as booking behavior, or preferred hotel types. This can help tailor marketing strategies and services to different customer groups.
#
# 5. Cancellation Analysis: Examine factors contributing to booking cancellations, such as lead time, booking channel, or room type.
#
# 6. Booking Channel Analysis: Analyze the distribution of bookings through different channels, such as Corporate bookings, Direct, travel agencies, or online platforms. Assess the effectiveness of each channel and identify opportunities for improvement.
#
# 7. Data Visualization: Utilize various data visualization techniques, including bar charts, line plots, heatmaps, and scatter plots, to present the findings in a visually compelling manner.
#
# 8. Recommendations: Summarize the key findings and provide actionable recommendations to hotel management. These recommendations should be based on data-driven insights to enhance customer experience, increase customer retention, and improve overall hotel performance.
#
# By conducting a thorough hotel booking analysis, this project aims to provide valuable insights that can drive better decision-making, improve customer satisfaction, and increase the hotel's competitiveness in the hospitality industry. The analysis can also help identify areas for operational efficiency and guide marketing efforts to attract and retain customers effectively.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/sudipsingh104/EDA_Hotel

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# we have to find which factors affeact the hotel booking behaviour. using the given datset of year 2015, 2016, 2017. we have several variable to find better insight of booking like cancelation , peak motnth, lead time, total guest and so on.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Find insight which helps to improve service and boost the revenues. and find technique may use to grow no of booking.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
import seaborn as sns
from mpl_toolkits.mplot3d.axes3d import Axes
from sqlalchemy import label
from datetime import datetime
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
hotelbooking_df=pd.read_csv('/content/drive/MyDrive/DA ALMABETTER/EDA Project/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotelbooking_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Total Rows Count is = ',hotelbooking_df.shape[0])
print('Total Column Count is = ',hotelbooking_df.shape[1])
# Out:
# Total Rows Count is =  119390
# Total Column Count is =  32

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotelbooking_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print('Duplicate rows in Data is : ',len(hotelbooking_df[hotelbooking_df.duplicated()]))
# Out:
# Duplicate rows in Data is :  31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
hotelbooking_df.isnull().sum().sort_values(ascending=False)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# hotel                                  0
# previous_cancellations                 0
# days_in_waiting_list                   0
# customer_type                          0
# adr                                    0
# required_car_parking_spaces            0
# total_of_special_requests              0
# reservation_status                     0
# previous_bookings_not_canceled         0
# is_repeated_guest                      0
# is_canceled                            0
# distribution_channel                   0
# market_segment                         0
# meal                                   0
# babies                                 0
# ...

# %%
# Visualizing the missing values
sns.heatmap(hotelbooking_df.isnull(), cbar=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# We have the hotel booking data in two category one is resort hotel and another one is city hotel. there are around 32 k duplicate values which mislead our analysis. we also clearly see that most of custmer didn't tell their company name. we also sees that there is no null values except country, agent and company field.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotelbooking_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotelbooking_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in hotelbooking_df.columns:
  print(f'Unique Value in variable {col} : {list(hotelbooking_df[col].unique())}')
  print()
# Out:
# Unique Value in variable hotel : ['Resort Hotel', 'City Hotel']
#
# Unique Value in variable is_canceled : [0, 1]
#
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df=hotelbooking_df.copy()
df.drop_duplicates(inplace=True) #Removing Duplicate

# %% [markdown]
# As we there are 4 variable with Null values from which company and agent are the variable whoes not required to handle because it may be the guest whoes not book room from a company or by any agent. As we see there is some countries also han null value we can remove it by others. And we also sees that there is some null value in children as well and it's very less null values we can remove  it using the mode.

# %%
#Handling Nan
df['company'].fillna(0, inplace=True)
df['agent'].fillna(0, inplace=True)
df['country'].fillna("Other", inplace=True)
df['children'].fillna(0, inplace=True)
df.isnull().sum().sort_values(ascending=False)
# Out:
# hotel                             0
# is_canceled                       0
# reservation_status                0
# total_of_special_requests         0
# required_car_parking_spaces       0
# adr                               0
# customer_type                     0
# days_in_waiting_list              0
# company                           0
# agent                             0
# deposit_type                      0
# booking_changes                   0
# assigned_room_type                0
# reserved_room_type                0
# previous_bookings_not_canceled    0
# previous_cancellations            0
# is_repeated_guest                 0
# distribution_channel              0
# market_segment                    0
# country                           0
# meal                              0
# babies                            0
# children                          0
# adults                            0
# stays_in_week_nights              0
# stays_in_weekend_nights           0
# ...

# %% [markdown]
# Type Change
#
# Some variable need type change. such as date col which is as object need to convert as datetime format and children in float which is not possible. So we convert children as int64.

# %%
df[['children','agent','company']]=df[['children','agent','company']].astype(int)
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])
df['arrival_date_year']=df['arrival_date_year'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  object
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
df['total_guest']=df['adults']+df['children']+df['babies']
df['total_stay']=df['stays_in_week_nights']+df['stays_in_weekend_nights']
df.drop(df[df['total_guest']==0].index, inplace= True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I removed duplicates form the data. i replaced nan of company and agent from 0 which repesnt as blank value. i also replace nan of country variable with others. i replaced nam of children with 0 which is mode of the children . i added a col of total guest which is the of adult + children + babies. There are some rows available where total guest is 0 so i removed these rows.i Also added a column named total_stay which is sum of 'stays_in_week_nights' & 'stays_in_weekend_nights'.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
sns.scatterplot(data=df, x='total_stay', y='adr')
# Out:
# <Axes: xlabel='total_stay', ylabel='adr'>

# %%
df.drop(df[df['adr']>5000].index, inplace=True) # i removed outliers from the data.
sns.scatterplot(data=df, x='total_stay', y='adr')
# Out:
# <Axes: xlabel='total_stay', ylabel='adr'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i choose this graph because i have two attribute and i have to see how adr varies with stay duration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We clearly sees that adr if the stay is less then adr is high and if stay is long then adr is low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# So we say that if customer book rooms for long duration they have more chance to get room in low price.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'total_guest',
#        'total_stay'],
#       dtype='object')

# %%
# Chart - 2 visualization code
df1=df.groupby(['agent'], as_index=False).agg({'hotel':'count'})
df1=df1[df1['agent']!=0]
df1=df1.sort_values(['hotel'], ascending=False).head(10) #selection top 10 performing agent.
df1.rename(columns={'hotel':'Total No Of Booking'}, inplace=True)
sns.barplot(data=df1, x='agent', y= 'Total No Of Booking')
# Out:
# <Axes: xlabel='agent', ylabel='Total No Of Booking'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have two variable one is catagrical and anther one is numeric and i have to compare the categrical data so i choose the barplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can clearly see that agent no 9 has the most bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as we see these agent performing good so we encourage them to grow more.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
df1=df.groupby(['country'], as_index=False).agg({'hotel':'count'})
#df1=df1[df1['agent']!=0]
df1=df1.sort_values(['hotel'], ascending=False).head(10) #selection top 10 performing agent.
df1.rename(columns={'hotel':'Total No Of Booking'}, inplace=True)
sns.barplot(data=df1, x='country', y= 'Total No Of Booking')
# Out:
# <Axes: xlabel='country', ylabel='Total No Of Booking'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I have two variable one is catagrical and anther one is numeric and i have to compare the categrical data so i choose the barplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We clearly sees that PRT country has most bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps to work accordingly.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
df1=df[df['is_canceled']!=1].groupby(['hotel'], as_index=False).agg({'is_canceled':'count'})
df1.rename(columns={'is_canceled':'Bookings'},inplace=True)
sns.barplot(data=df1, x='hotel', y= 'Bookings')
# Out:
# <Axes: xlabel='hotel', ylabel='Bookings'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have two variable one is catagrical and anther one is numeric and i have to compare the categrical data so i choose the barplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# with this insight we can see that city hotel has the most booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customer prefer city hotels so we focus on city hotel.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
df1=df.groupby(['hotel'], as_index=False).agg({'adr':'mean'})
df1.rename(columns={'adr':'Average adr'},inplace=True)
sns.barplot(data=df1, x='hotel', y= 'Average adr')
# Out:
# <Axes: xlabel='hotel', ylabel='Average adr'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have two variable one is catagrical and anther one is numeric and i have to compare the categrical data so i choose the barplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we see that city hotel avg adr is slight more then resort hotel adr.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# That city hotel avg cost is more then resort hotel

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
df1=df[df['is_canceled']==1]
sns.histplot(x='hotel', data=df1)
# Out:
# <Axes: xlabel='hotel', ylabel='Count'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# because we have to see the count of city hotel and resort hotel booking then hist automatically provide the count so we use this.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see that city hotel has the most bokkings which is canceled then resort hotel.
#
# ---

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it shows that we have too many cancelation in city hotel so we have to work for reducing the cancellation.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
corr_matrix = df[['total_stay', 'total_guest','adr']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap: ADR')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap: ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i choose this because i wan t show the relation between total stay, total guest and adr so i choose the heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that total no guest and stay impact the adr.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
group_by_dc = df.groupby(['distribution_channel'])
d1 = pd.DataFrame(round((group_by_dc.size()/df.shape[0])*100,2)).reset_index().rename(columns = {0: 'Booking_%'})
plt.figure(figsize = (8,8))
data = d1['Booking_%']
labels = d1['distribution_channel']
plt.pie(x=data, autopct="%.2f%%", explode=[0.05]*5, labels=labels, pctdistance=0.5)
plt.title("Booking % by distribution channels", fontsize=14);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# chossing pi plot because i shows the same time of data category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TA/TO distribution chanel has most bokking  followed by deirect and then corporate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we can see that there is a distribution chanel which has very less booking is GDS so we do something to grow GDS chennel or shut it down or invest in others chennel.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
group_by_dc = df.groupby(['is_canceled'])
d1 = pd.DataFrame(round((group_by_dc.size()/df.shape[0])*100,2)).reset_index().rename(columns = {0: 'Booking_%'})
plt.figure(figsize = (8,8))
data = d1['Booking_%']
labels = d1['is_canceled']
plt.pie(x=data, autopct="%.2f%%", explode=[0.05]*2, labels=labels, pctdistance=0.5)
plt.title("Canceled booking % Vs not canceled %", fontsize=14);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Cnaceled and not canceled is booking two parts so i choose to show the % cancelleation and booking. pie chart is good way show percentage.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# cancelation is 27% od total booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# with this insight we clearly says that we need to reduce the cancelation.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
df1=df.groupby(['arrival_date_year','hotel'], as_index=False).agg({'country':'count'}).rename(columns={'country':'Bookings','arrival_date_year':'Year'})
sns.lineplot(x='Year', y='Bookings', data=df1, hue='hotel')
plt.title('Booking over the Year')
# Out:
# Text(0.5, 1.0, 'Booking over the Year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I uses line chart because line chart is good shows trends over the time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we clearly see that booking is incresing in year 2016 and we also sees decrease in 2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see a negtive booking pattern in 2017. it may be alrmaing or company has to improves.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
group_by_dc = df.groupby(['meal'])
d1 = pd.DataFrame(round((group_by_dc.size()/df.shape[0])*100,2)).reset_index().rename(columns = {0: 'Booking_%'})
plt.figure(figsize = (8,8))
data = d1['Booking_%']
labels = d1['meal']
plt.pie(x=data, autopct="%.2f%%", explode=[0.05]*5, labels=labels, pctdistance=0.5)
plt.title("Meal Choise percentage", fontsize=14);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose pi chart because i have to visulise section of a variable how it's distributed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can clearly sees that BB meal is mostly preffered by the custmers followed by SC and HB Respectivly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we can improve our BB meal and try make this meal cost efficient.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
df1=df.groupby(['arrival_date_month','hotel'], as_index=False).agg({'total_guest':'count'}).rename(columns={'total_guest':'Bookings','arrival_date_month':'Month'})
month_mapping = {
    'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12
}

# Convert Month column to datetime format
df1['MonthNumber'] = df1['Month'].replace(month_mapping, regex=True)

# Sort dataframe by MonthNumber and Year
#df1 = df.sort_values(by='MonthNumber')
df1.sort_values(['MonthNumber'], inplace=True)
sns.set_style("whitegrid")
plt.figure(figsize=(15, 6))
sns.lineplot(x='Month', y='Bookings', data=df1, hue='hotel')
plt.title('Booking over the Months')
# Out:
# Text(0.5, 1.0, 'Booking over the Months')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I uses line chart because line chart is good shows trends over the time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can clearly sees that bokking is increses in month of Jul and aug.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For business poitn of views hotel must be prepared for more guest in the month of jul and aug. And for customer prospective coustomers has to book early for month of jul and aug.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
df1=df.groupby(['arrival_date_month','hotel'], as_index=False).agg({'adr':'mean'}).rename(columns={'adr':'Average adr','arrival_date_month':'Month'})
month_mapping = {
    'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6,
    'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12
}

# Convert Month column to datetime format
df1['MonthNumber'] = df1['Month'].replace(month_mapping, regex=True)

# Sort dataframe by MonthNumber and Year
#df1 = df.sort_values(by='MonthNumber')
df1.sort_values(['MonthNumber'], inplace=True)
sns.set_style("whitegrid")
plt.figure(figsize=(15, 6))
sns.lineplot(x='Month', y='Average adr', data=df1, hue='hotel')
plt.title('Avg ADR over the Months')
# Out:
# Text(0.5, 1.0, 'Avg ADR over the Months')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I uses line chart because line chart is good shows trends over the time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see that deviation in adr is very less through out the year. while resort hotel adr drastically increasses in moth of jul &  aug and same way goes down in sep and oct.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we can say that resort hotel may work for improve their booking in other months.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
corr_mat=df[['hotel', 'is_canceled', 'lead_time', 'arrival_date_year','arrival_date_month', 'meal', 'adr', 'country', 'distribution_channel','is_repeated_guest', 'previous_cancellations',
       'previous_bookings_not_canceled', 'days_in_waiting_list', 'reservation_status_date', 'total_guest',
       'total_stay']].corr()
sns.heatmap(corr_mat, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <ipython-input-31-2f4194390bd8>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   'total_stay']].corr()
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i choose this graph beacuse i have to the relation between above variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# total stay and adr is increses simultaneously.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
numeric_columns = ['lead_time', 'arrival_date_year', 'arrival_date_month','total_stay','total_guest',
                  'previous_cancellations', 'previous_bookings_not_canceled',
                   'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

sns.set(style="ticks")
sns.pairplot(df[numeric_columns], diag_kind='kde')
plt.suptitle('Pair Plot of Hotel Booking Features', y=1.02)
# Out:
# Text(0.5, 1.02, 'Pair Plot of Hotel Booking Features')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To sees relationship between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can sees that there is relation between many variable i.e. total special request and lead time.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# Identifying seasonal trends helps in planning staffing, marketing, and promotional activities. we can an data to recognize patterns in bookings, events, and demand throughout the year to align strategies accordingly.
# Efficiently managing resources like housekeeping, food and beverage, and amenities is crucial for cost control.Use data to optimize inventory management, staff schedules, and supply chains, reducing waste and increasing efficiency. Understanding customer segments can help tailor marketing efforts and improve services for specific group.Perform clustering analysis on customer data to identify segments based on demographics, preferences, and past spending.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# An Exploratory Data Analysis (EDA) of hotel booking data can provide valuable insights into booking patterns, customer behavior, and other trends that can influence business decisions.
#
# After conducting an in-depth Exploratory Data Analysis (EDA) on the hotel booking dataset, several key findings have emerged that shed light on various aspects of booking patterns, customer behavior, and potential opportunities for improving operational efficiency and guest experiences.
#
# 1. Booking Patterns:
#
#     Bookings are more frequent during the month of July and August being the peak booking periods.
#
# 2. Cancellation Trends:
#
#     The cancellation rate is relatively higher in city hotel in camparision of resort hotel.
#
# 3. Customer Segmentation:
#
#     Using clustering analysis, four distinct customer segments were identified based on booking behavior and preferences: Business Travelers, Leisure Travelers, Long Stay Guests, and Family Travelers.
#     Each segment exhibits unique characteristics and preferences, which can inform personalized marketing strategies and service offerings.
#
# 4. Revenue Opportunities:
#
#     Dynamic pricing strategies could be implemented to capitalize on peak seasons and events, potentially increasing revenue.
#
# 6. Operational Improvements:
#
#     Housekeeping schedules can be optimized based on check-in and check-out times, reducing waiting times for guests.
#     Efficient allocation of resources during peak booking periods can enhance overall guest experience and staff productivity.
#
# 7. Marketing Effectiveness:
#
#     Marketing campaigns launched during low-demand periods have shown potential in increasing bookings and revenue, indicating the need for more targeted promotional effortsin the countries where booking is less and in the month when is booking is less.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
